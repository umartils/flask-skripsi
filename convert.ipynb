# %%
import tensorflow as tf

# Load model lama
old_model = tf.keras.models.load_model(
    "model/best_fusion_model(light)_(2025-11-06_18-17).h5",
    compile=False
)

# Simpan ulang dengan format SavedModel (lebih stabil)
old_model.save("model/cnn_model_fixed.keras")
